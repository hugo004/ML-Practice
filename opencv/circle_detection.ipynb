# %% [markdown]
# # Reference
# https://pyimagesearch.com/2014/07/21/detecting-circles-images-using-opencv-hough-circles/

# %%
import cv2
import numpy as np

from matplotlib import pyplot as plt

# %%
image = cv2.imread('../resources/shape.png')
output = image.copy()
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT, 1.2, 100)
if circles is not None:
    # decrease dimension to 2d array
    circles = circles[0,:].astype('int')


    for x, y, radius in circles:
        cv2.circle(output, (x, y), radius, (0, 255, 0), 3)
        cv2.circle(output, (x,y), 5, (255, 0, 0), -1)

    plt.imshow(np.vstack([image, output]))
